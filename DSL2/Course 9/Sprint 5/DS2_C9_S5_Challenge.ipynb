# %%
# data manipulation
import numpy as np
import pandas as pd

# plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore')

# %%
# import data
df = pd.read_csv("D:\Data Science\Course 9\DS2_C5_S5_OldCars_Data_Challenge.csv")
df
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
df.sample(5)
# Out:
#       S.No.                             Name   Location  Year  \
# 4044   4044                    Volvo XC60 D5  Ahmedabad  2011
# 4453   4453  Maruti Zen Estilo 1.1 VXI BSIII  Ahmedabad  2007
# 1085   1085         Hyundai Creta 1.6 VTVT S      Kochi  2016
# 683     683           Honda Amaze EX i-Dtech  Bangalore  2013
# 4843   4843               Maruti Celerio LXI  Hyderabad  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 4044             173000    Diesel    Automatic      First   13.5 kmpl
# 4453              75180    Petrol       Manual      First   18.2 kmpl
# 1085              36855    Petrol       Manual     Second  15.29 kmpl
# 683               33800    Diesel       Manual     Second   25.8 kmpl
# 4843              58470    Petrol       Manual      First   23.1 kmpl
#
#        Engine      Power  Seats New_Price  Price
# 4044  2400 CC    215 bhp    5.0       NaN  12.00
# 4453  1061 CC     64 bhp    5.0       NaN   1.65
# ...

# %%
df.dtypes
# Out:
# S.No.                  int64
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# New_Price             object
# Price                float64
# dtype: object

# %% [markdown]
# check that if there is null value or not

# %%
df.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %% [markdown]
# Fill the null or nan values with mode and mean of that column

# %%
for column in df.columns:
    if df[column].dtype == 'float64' or df[column].dtype == 'int64':
        # Calculate mean of the column
        mean = df[column].mean()
        print(f"Mean of {column}: {mean}")
        # Fill null values with the mean
        df[column].fillna(mean, inplace=True)
    elif df[column].dtype == 'object':
        # Calculate mode of the column
        mode = df[column].mode().values[0]
        print(f"Mode of {column}: {mode}")
        # Fill null values with the mode
        df[column].fillna(mode, inplace=True)

# Verify if all the null values have been filled
print(df.isnull().sum().sum())
# Out:
# Mean of S.No.: 3626.0
# Mode of Name: Mahindra XUV500 W8 2WD
# Mode of Location: Mumbai
# Mean of Year: 2013.3653660554253
# Mean of Kilometers_Driven: 58699.063146284294
# Mode of Fuel_Type: Diesel
# Mode of Transmission: Manual
# Mode of Owner_Type: First
# Mode of Mileage: 17.0 kmpl
# Mode of Engine: 1197 CC
# Mode of Power: 74 bhp
# Mean of Seats: 5.279722222222222
# Mode of New_Price: 33.36 Lakh
# Mean of Price: 9.479468350224273
# 0

# %%
df.isnull().sum()
# Out:
# S.No.                0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# New_Price            0
# Price                0
# dtype: int64

# %%
df_new = df
df_new = df.drop(columns = ["S.No."])

# %%
df_new.describe()
# Out:
#               Name     Location         Year  Kilometers_Driven    Fuel_Type  \
# count  7253.000000  7253.000000  7253.000000       7.253000e+03  7253.000000
# mean    998.547773     5.622363  2013.365366       5.869906e+04     2.370330
# std     577.521935     2.969663     3.254421       8.442772e+04     1.504603
# min       0.000000     0.000000  1996.000000       1.710000e+02     0.000000
# 25%     514.000000     3.000000  2011.000000       3.400000e+04     1.000000
# 50%    1017.000000     6.000000  2014.000000       5.341600e+04     1.000000
# 75%    1434.000000     8.000000  2016.000000       7.300000e+04     4.000000
# max    2040.000000    10.000000  2019.000000       6.500000e+06     4.000000
#
#        Transmission   Owner_Type      Mileage       Engine        Power  \
# count   7253.000000  7253.000000  7253.000000  7253.000000  7253.000000
# mean       0.717496     0.375982   230.173032    53.165311   216.255894
# ...

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for column in df_new.columns:
    if df_new[column].dtype == 'object':
        df_new[column] = le.fit_transform(df[column])

# %%
df_new.sample(5)
# Out:
#       Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 354    210         8  2011              21000          4             1
# 2060     9         1  2014              24000          1             0
# 6634  1980         6  2015              62766          1             1
# 53    1265         4  2013              65650          1             1
# 4789   716         2  2012              41000          1             0
#
#       Owner_Type  Mileage  Engine  Power  Seats  New_Price      Price
# 354            2      231     147    277    5.0        268   0.950000
# 2060           0      200      60    128    5.0        268  25.000000
# 6634           0      295      38    360    5.0        268   9.479468
# 53             0      421      14    311    5.0        268   3.850000
# 4789           0      263      40     60    5.0        268   6.250000

# %%
column_correlation = df_new.corr()
column_correlation
# Out:
#                        Name  Location      Year  Kilometers_Driven  Fuel_Type  \
# Name               1.000000  0.033469  0.016406           0.031892  -0.072004
# Location           0.033469  1.000000 -0.027455          -0.035586   0.113209
# Year               0.016406 -0.027455  1.000000          -0.187859  -0.131888
# Kilometers_Driven  0.031892 -0.035586 -0.187859           1.000000  -0.109530
# Fuel_Type         -0.072004  0.113209 -0.131888          -0.109530   1.000000
# Transmission       0.136026  0.048700 -0.099975           0.031166   0.125346
# Owner_Type        -0.026578 -0.029547 -0.385503           0.088485   0.048425
# Mileage           -0.040560  0.019332  0.287083          -0.078287  -0.101094
# Engine             0.059323 -0.041717 -0.060849           0.026921  -0.063172
# Power             -0.099954  0.026886  0.025195          -0.050574   0.170280
# Seats              0.162929 -0.034488  0.008137           0.090162  -0.294250
# ...

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(column_correlation,annot=True,linewidths=.5, ax=ax)

plt.show()
