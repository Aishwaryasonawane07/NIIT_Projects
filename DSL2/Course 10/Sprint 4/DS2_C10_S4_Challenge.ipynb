# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\Data Science\Course 10\DS2_C6_S3_CarSales_Data_Practice.csv")
df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
df.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
df=df.drop(["__year_resale_value","Latest_Launch"],axis=1)
df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0        Acura  Integra              16.919    Passenger               21.50
# 1        Acura       TL              39.384    Passenger               28.40
# 2        Acura       CL              14.114    Passenger                 NaN
# 3        Acura       RL               8.588    Passenger               42.00
# 4         Audi       A4              20.397    Passenger               23.99
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
# 2          3.2       225.0      106.9   70.6   192.0        3.470
# 3          3.5       210.0      114.6   71.4   196.6        3.850
# 4          1.8       150.0      102.6   68.2   178.0        2.998
#
#    Fuel_capacity  Fuel_efficiency  Power_perf_factor
# ...

# %%
df.isna().sum()
# Out:
# Manufacturer          0
# Model                 0
# Sales_in_thousands    0
# Vehicle_type          0
# Price_in_thousands    2
# Engine_size           1
# Horsepower            1
# Wheelbase             1
# Width                 1
# Length                1
# Curb_weight           2
# Fuel_capacity         1
# Fuel_efficiency       3
# Power_perf_factor     2
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isna().sum()
# Out:
# Manufacturer          0
# Model                 0
# Sales_in_thousands    0
# Vehicle_type          0
# Price_in_thousands    0
# Engine_size           0
# Horsepower            0
# Wheelbase             0
# Width                 0
# Length                0
# Curb_weight           0
# Fuel_capacity         0
# Fuel_efficiency       0
# Power_perf_factor     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Manufacturer"]=le.fit_transform(df["Manufacturer"])
df["Model"]=le.fit_transform(df["Model"])
df["Vehicle_type"]=le.fit_transform(df["Vehicle_type"])
df.head()
# Out:
#    Manufacturer  Model  Sales_in_thousands  Vehicle_type  Price_in_thousands  \
# 0             0     78              16.919             1               21.50
# 1             0    139              39.384             1               28.40
# 3             0    112               8.588             1               42.00
# 4             1      8              20.397             1               23.99
# 5             1      9              18.780             1               33.95
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
# 3          3.5       210.0      114.6   71.4   196.6        3.850
# 4          1.8       150.0      102.6   68.2   178.0        2.998
# 5          2.8       200.0      108.7   76.1   192.0        3.561
#
#    Fuel_capacity  Fuel_efficiency  Power_perf_factor
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
x=scale.fit_transform(df)

# %%
df
# Out:
#      Manufacturer  Model  Sales_in_thousands  Vehicle_type  \
# 0               0     78              16.919             1
# 1               0    139              39.384             1
# 3               0    112               8.588             1
# 4               1      8              20.397             1
# 5               1      9              18.780             1
# ..            ...    ...                 ...           ...
# 152            29    143               3.545             1
# 153            29    122              15.245             1
# 154            29    144              17.531             1
# 155            29     24               3.493             1
# 156            29    123              18.969             1
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# ...

# %%
plt.scatter(x[8], x[9], s=15, c='g')
plt.title("Cars", fontsize = 20)
plt.xlabel("width", fontsize = 14)
plt.ylabel("length", fontsize=14)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
# Select features to use for clustering
X = df[['Width','Length']]

# Standardize the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Apply DBSCAN clustering algorithm
dbscan = DBSCAN(eps=0.35, min_samples=18)
labels = dbscan.fit_predict(X)

# Create scatter plot of clusters
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
plt.xlabel('Width')
plt.ylabel('Length')
plt.title('DBSCAN Clustering of Cars Data')
plt.show()

# %% [markdown]
# Interpretation : Data is not properly cluter

# %% [markdown]
# # Task 3

# %%
X = pd.DataFrame(X)

# %%
from sklearn.neighbors import NearestNeighbors
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(X[[0,1]])
distances, indices= nbrs.kneighbors(X[[0,1]])

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.figure(figsize=(15,8))
plt.plot(distances)
plt.axhline(y=0.3, color= "r", linestyle ="--")
plt.title("k-distance graph", fontsize=20)
plt.xlabel("Data points sorted by distance", fontsize =14)
plt.ylabel("Epsilon (Actual distance value)", fontsize = 14)
plt.show()

# %% [markdown]
# # Task 4

# %%
X = df.drop("Price_in_thousands", axis=1)
y = df["Price_in_thousands"]

# %%
X = pd.DataFrame(X)

# %%
X
# Out:
#      Manufacturer  Model  Sales_in_thousands  Vehicle_type  Engine_size  \
# 0               0     78              16.919             1          1.8
# 1               0    139              39.384             1          3.2
# 3               0    112               8.588             1          3.5
# 4               1      8              20.397             1          1.8
# 5               1      9              18.780             1          2.8
# ..            ...    ...                 ...           ...          ...
# 152            29    143               3.545             1          1.9
# 153            29    122              15.245             1          2.4
# 154            29    144              17.531             1          2.4
# 155            29     24               3.493             1          2.3
# 156            29    123              18.969             1          2.9
#
#      Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# ...

# %%
y = pd.DataFrame(y)

# %%
y
# Out:
#      Price_in_thousands
# 0                 21.50
# 1                 28.40
# 3                 42.00
# 4                 23.99
# 5                 33.95
# ..                  ...
# 152               24.40
# 153               27.50
# 154               28.80
# 155               45.50
# 156               36.00
#
# [152 rows x 1 columns]

# %%
eps_optimum = 0.3
for min_samples_list in [10,11,12,13]:
    Clusterer = DBSCAN(eps = eps_optimum, min_samples= min_samples_list)
    Cluster_labels = Clusterer.fit_predict(X)
    #print(Cluster_labels)
    
    x=  Cluster_labels +2 
    y= np.bincount(x)
    
    ii = np.nonzero(y)[0]
    
    results = list(zip(ii,y[ii]))
    #print(results)
    print("eps", eps_optimum, "| min samples =", min_samples_list, "| Number of clusters obtained :", results)
# Out:
# eps 0.3 | min samples = 10 | Number of clusters obtained : [(1, 152)]
# eps 0.3 | min samples = 11 | Number of clusters obtained : [(1, 152)]
# eps 0.3 | min samples = 12 | Number of clusters obtained : [(1, 152)]
# eps 0.3 | min samples = 13 | Number of clusters obtained : [(1, 152)]

# %%
dbscan_opt=DBSCAN(eps=0.3,min_samples=12)
dbscan_opt.fit(X)
# Out:
# DBSCAN(eps=0.3, min_samples=12)

# %%
X['DBSCAN_opt_labels']=dbscan_opt.labels_
X['DBSCAN_opt_labels'].value_counts()
# Out:
# -1    152
# Name: DBSCAN_opt_labels, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.datasets import make_circles
import warnings
import matplotlib
warnings.filterwarnings("ignore")
import matplotlib.colors as mcolors

# %%
colors = ["purple","red","blue","green"]

# %%
import matplotlib.pyplot as plt
colors = list(mcolors.TABLEAU_COLORS.values())
plt.scatter(X, c=X['DBSCAN_opt_labels'],cmap=matplotlib.colors.ListedColormap(colors),s=15)
print("Silhouette Coefficient: %0.3f" % metrics.silhouette_score(X, X['DBSCAN_opt_labels']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22132\663524760.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 colors = list(mcolors.TABLEAU_COLORS.values())
# ----> 3 plt.scatter(X, c=X['DBSCAN_opt_labels'],cmap=matplotlib.colors.ListedColormap(colors),s=15)
#       4 print("Silhouette Coefficient: %0.3f" % metrics.silhouette_score(X, X['DBSCAN_opt_labels']))
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Define a list of colors to be used in the color map
colors = list(mcolors.TABLEAU_COLORS.values())

plt.scatter(X["Width"], X["Length"], c=X['DBSCAN_opt_labels'], cmap=matplotlib.colors.ListedColormap(colors), s=15)
print("Silhouette Coefficient: %0.3f" % metrics.silhouette_score(X, X['DBSCAN_opt_labels']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22132\7098848.py in <module>
#       6
#       7 plt.scatter(X["Width"], X["Length"], c=X['DBSCAN_opt_labels'], cmap=matplotlib.colors.ListedColormap(colors), s=15)
# ----> 8 print("Silhouette Coefficient: %0.3f" % metrics.silhouette_score(X, X['DBSCAN_opt_labels']))
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115         else:
#     116             X, labels = X[indices], labels[indices]
# --> 117     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#     118
#     119
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     225     n_samples = len(labels)
# ...
