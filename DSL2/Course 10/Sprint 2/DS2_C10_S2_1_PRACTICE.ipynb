# %% [markdown]
# ## Importing neccessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cities=pd.read_csv("D:\Data Science\Course 10\DS2_C6_S2_Cities_Data_Practice.csv")
cities.head()
# Out:
#                City        Country
# 0           Oakland  United States
# 1          Oakville         Canada
# 2  Oaxaca de Juárez         Mexico
# 3        Oberhausen        Germany
# 4           Obihiro          Japan

# %%
costofl=pd.read_csv(r"D:\Data Science\Course 10\DS2_C6_S2_MoveHubCostOfLiving_Data_Practice.csv")
costofl.head()
# Out:
#        City  Cappuccino  Cinema   Wine  Gasoline  Avg Rent  \
# 0  Lausanne        3.15   12.59   8.40      1.32   1714.00
# 1    Zurich        3.28   12.59   8.40      1.31   2378.61
# 2    Geneva        2.80   12.94  10.49      1.28   2607.95
# 3     Basel        3.50   11.89   7.35      1.25   1649.29
# 4     Perth        2.87   11.43  10.08      0.97   2083.14
#
#    Avg Disposable Income
# 0                4266.11
# 1                4197.55
# 2                3917.72
# 3                3847.76
# 4                3358.55

# %%
qual=pd.read_csv(r"D:\Data Science\Course 10\DS2_C6_S2_MoveHubQualityOfLife_Data_Practice.csv")
qual.head()
# Out:
#            City  Movehub Rating  Purchase Power  Health Care  Pollution  \
# 0       Caracas           65.18           11.25        44.44      83.45
# 1  Johannesburg           84.08           53.99        59.98      47.39
# 2     Fortaleza           80.17           52.28        45.46      66.32
# 3   Saint Louis           85.25           80.40        77.29      31.33
# 4   Mexico City           75.07           24.28        61.76      18.95
#
#    Quality of Life  Crime Rating
# 0             8.61         85.70
# 1            51.26         83.93
# 2            36.68         78.65
# 3            87.51         78.13
# 4            27.91         77.86

# %%
world=pd.read_csv("D:\Data Science\Course 10\DS2_C6_S2_WorldCities_Data_Practice.csv")
world
# Out:
#               city   city_ascii      lat       lng      country iso2 iso3  \
# 0            Tokyo        Tokyo  35.6897  139.6922        Japan   JP  JPN
# 1          Jakarta      Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2            Delhi        Delhi  28.6600   77.2300        India   IN  IND
# 3           Mumbai       Mumbai  18.9667   72.8333        India   IN  IND
# 4           Manila       Manila  14.5958  120.9772  Philippines   PH  PHL
# ...            ...          ...      ...       ...          ...  ...  ...
# 26564         Nord         Nord  81.7166  -17.8000    Greenland   GL  GRL
# 26565  Timmiarmiut  Timmiarmiut  62.5333  -42.2167    Greenland   GL  GRL
# 26566  Cheremoshna  Cheremoshna  51.3894   30.0989      Ukraine   UA  UKR
# 26567    Ambarchik    Ambarchik  69.6510  162.3336       Russia   RU  RUS
# 26568      Nordvik      Nordvik  74.0165  111.5100       Russia   RU  RUS
#
#                admin_name  capital  population          id
# 0                   Tōkyō  primary  37977000.0  1392685764
# 1                 Jakarta  primary  34540000.0  1360771077
# 2                   Delhi    admin  29617000.0  1356872604
# 3             Mahārāshtra    admin  23355000.0  1356226629
# 4                  Manila  primary  23088000.0  1608618140
# ...                   ...      ...         ...         ...
# 26564          Sermersooq      NaN        10.0  1304217709
# 26565            Kujalleq      NaN        10.0  1304206491
# 26566   Kyyivs’ka Oblast’      NaN         0.0  1804043438
# 26567    Sakha (Yakutiya)      NaN         0.0  1643739159
# 26568  Krasnoyarskiy Kray      NaN         0.0  1643587468
#
# [26569 rows x 11 columns]

# %%
world.shape,qual.shape,costofl.shape,cities.shape
# Out:
# ((26569, 11), (216, 7), (216, 7), (3543, 2))

# %% [markdown]
#  Rename city as "City" in world cities

# %%
world.rename(columns={"city":"City"},inplace=True)

# %%
world
# Out:
#               City   city_ascii      lat       lng      country iso2 iso3  \
# 0            Tokyo        Tokyo  35.6897  139.6922        Japan   JP  JPN
# 1          Jakarta      Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2            Delhi        Delhi  28.6600   77.2300        India   IN  IND
# 3           Mumbai       Mumbai  18.9667   72.8333        India   IN  IND
# 4           Manila       Manila  14.5958  120.9772  Philippines   PH  PHL
# ...            ...          ...      ...       ...          ...  ...  ...
# 26564         Nord         Nord  81.7166  -17.8000    Greenland   GL  GRL
# 26565  Timmiarmiut  Timmiarmiut  62.5333  -42.2167    Greenland   GL  GRL
# 26566  Cheremoshna  Cheremoshna  51.3894   30.0989      Ukraine   UA  UKR
# 26567    Ambarchik    Ambarchik  69.6510  162.3336       Russia   RU  RUS
# 26568      Nordvik      Nordvik  74.0165  111.5100       Russia   RU  RUS
#
#                admin_name  capital  population          id
# 0                   Tōkyō  primary  37977000.0  1392685764
# 1                 Jakarta  primary  34540000.0  1360771077
# 2                   Delhi    admin  29617000.0  1356872604
# 3             Mahārāshtra    admin  23355000.0  1356226629
# 4                  Manila  primary  23088000.0  1608618140
# ...                   ...      ...         ...         ...
# 26564          Sermersooq      NaN        10.0  1304217709
# 26565            Kujalleq      NaN        10.0  1304206491
# 26566   Kyyivs’ka Oblast’      NaN         0.0  1804043438
# 26567    Sakha (Yakutiya)      NaN         0.0  1643739159
# 26568  Krasnoyarskiy Kray      NaN         0.0  1643587468
#
# [26569 rows x 11 columns]

# %% [markdown]
# Sorting population column

# %%
world.sort_values(by="population",ascending=False)
# Out:
#            City city_ascii      lat       lng        country iso2 iso3  \
# 0         Tokyo      Tokyo  35.6897  139.6922          Japan   JP  JPN
# 1       Jakarta    Jakarta  -6.2146  106.8451      Indonesia   ID  IDN
# 2         Delhi      Delhi  28.6600   77.2300          India   IN  IND
# 3        Mumbai     Mumbai  18.9667   72.8333          India   IN  IND
# 4        Manila     Manila  14.5958  120.9772    Philippines   PH  PHL
# ...         ...        ...      ...       ...            ...  ...  ...
# 9469         Wé         We -20.9000  167.2667  New Caledonia   NC  NCL
# 9470    Preševo    Presevo  42.3067   21.6500         Serbia   RS  SRB
# 9471  Bujanovac  Bujanovac  42.4667   21.7667         Serbia   RS  SRB
# 9472   Kitamilo   Kitamilo   0.2222   33.2061         Uganda   UG  UGA
# 9473   Tarrafal   Tarrafal  15.2833  -23.7667     Cabo Verde   CV  CPV
#
#          admin_name  capital  population          id
# 0             Tōkyō  primary  37977000.0  1392685764
# 1           Jakarta  primary  34540000.0  1360771077
# 2             Delhi    admin  29617000.0  1356872604
# 3       Mahārāshtra    admin  23355000.0  1356226629
# 4            Manila  primary  23088000.0  1608618140
# ...             ...      ...         ...         ...
# 9469  Province Îles    admin         NaN  1540672599
# 9470        Preševo    admin         NaN  1688970219
# 9471      Bujanovac    admin         NaN  1688743477
# 9472         Buvuma    admin         NaN  1800610172
# 9473       Tarrafal    admin         NaN  1132834308
#
# [26569 rows x 11 columns]

# %% [markdown]
# Dropping Duplicates in city column

# %%
world.drop_duplicates(subset="City",keep='first',inplace=True)

# %%
world=world.merge(cities,on="City",how="left")
step1=qual.merge(costofl,on="City",how="left")
final=world.merge(step1,on="City")

# %%
final.isna().sum()
# Out:
# City                      0
# city_ascii                0
# lat                       0
# lng                       0
# country                   0
# iso2                      0
# iso3                      0
# admin_name                1
# capital                  60
# population                1
# id                        0
# Country                  18
# Movehub Rating            0
# Purchase Power            0
# Health Care               0
# Pollution                 0
# Quality of Life           0
# Crime Rating              0
# Cappuccino                0
# Cinema                    0
# Wine                      0
# Gasoline                  0
# Avg Rent                  0
# Avg Disposable Income     0
# dtype: int64

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207 entries, 0 to 206
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   City                   207 non-null    object
#  1   city_ascii             207 non-null    object
#  2   lat                    207 non-null    float64
#  3   lng                    207 non-null    float64
#  4   country                207 non-null    object
#  5   iso2                   207 non-null    object
#  6   iso3                   207 non-null    object
#  7   admin_name             206 non-null    object
#  8   capital                147 non-null    object
#  9   population             206 non-null    float64
#  10  id                     207 non-null    int64
#  11  Country                189 non-null    object
#  12  Movehub Rating         207 non-null    float64
#  13  Purchase Power         207 non-null    float64
#  14  Health Care            207 non-null    float64
#  15  Pollution              207 non-null    float64
#  16  Quality of Life        207 non-null    float64
#  17  Crime Rating           207 non-null    float64
#  18  Cappuccino             207 non-null    float64
#  19  Cinema                 207 non-null    float64
#  20  Wine                   207 non-null    float64
#  21  Gasoline               207 non-null    float64
#  22  Avg Rent               207 non-null    float64
#  23  Avg Disposable Income  207 non-null    float64
# dtypes: float64(15), int64(1), object(8)
# memory usage: 40.4+ KB

# %%
from sklearn.preprocessing import MinMaxScaler,LabelEncoder

# %% [markdown]
# ### Data preprocessing

# %%
numerics=final.select_dtypes(include=["float64","int64"])
numerics.drop("lat",axis=1,inplace=True)
numerics.drop("lng",axis=1,inplace=True)
numerics.drop("id",axis=1,inplace=True)
numerics=numerics.columns
numerics
# Out:
# Index(['population', 'Movehub Rating', 'Purchase Power', 'Health Care',
#        'Pollution', 'Quality of Life', 'Crime Rating', 'Cappuccino', 'Cinema',
#        'Wine', 'Gasoline', 'Avg Rent', 'Avg Disposable Income'],
#       dtype='object')

# %%
scaler=MinMaxScaler()
df_scaled=final.loc[:,numerics]
df_scaled=pd.DataFrame(scaler.fit_transform(df_scaled),columns=df_scaled.columns)
for item in df_scaled.columns:
    final[item]=df_scaled[item]
final
# Out:
#           City city_ascii      lat       lng        country iso2 iso3  \
# 0        Tokyo      Tokyo  35.6897  139.6922          Japan   JP  JPN
# 1      Jakarta    Jakarta  -6.2146  106.8451      Indonesia   ID  IDN
# 2        Delhi      Delhi  28.6600   77.2300          India   IN  IND
# 3       Mumbai     Mumbai  18.9667   72.8333          India   IN  IND
# 4       Manila     Manila  14.5958  120.9772    Philippines   PH  PHL
# ..         ...        ...      ...       ...            ...  ...  ...
# 202  Cambridge  Cambridge  43.3972  -80.3114         Canada   CA  CAN
# 203  Cambridge  Cambridge  43.3972  -80.3114         Canada   CA  CAN
# 204     Galway     Galway  53.2729   -9.0418        Ireland   IE  IRL
# 205     Sliema     Sliema  35.9125   14.5019          Malta   MT  MLT
# 206     Bogota     Bogota  40.8750  -74.0293  United States   US  USA
#
#       admin_name  capital  population  ...  Health Care Pollution  \
# 0          Tōkyō  primary    1.000000  ...     0.674830  0.330448
# 1        Jakarta  primary    0.909478  ...     0.232930  0.626596
# 2          Delhi    admin    0.779818  ...     0.720884  0.790197
# 3    Mahārāshtra    admin    0.614893  ...     0.500200  0.762714
# 4         Manila  primary    0.607861  ...     0.795022  0.705691
# ..           ...      ...         ...  ...          ...       ...
# 202      Ontario      NaN    0.003202  ...     0.807267  0.618697
# 203      Ontario      NaN    0.003202  ...     0.807267  0.618697
# 204       Galway    admin    0.001874  ...     0.427792  0.567734
# 205       Sliema    admin         NaN  ...     0.684014  0.733391
# 206   New Jersey      NaN    0.000000  ...     0.706243  0.157325
#
#      Quality of Life  Crime Rating  Cappuccino    Cinema      Wine  Gasoline  \
# 0           0.729262      0.062671    0.457711  0.128605  0.266028  0.565217
# 1           0.118163      0.511294    0.353234  0.020082  0.611990  0.236025
# 2           0.423428      0.567306    0.094527  0.007724  0.212739  0.478261
# 3           0.240884      0.333203    0.094527  0.015577  0.162365  0.509317
# 4           0.089448      0.747487    0.278607  0.012358  0.109076  0.490683
# ..               ...           ...         ...       ...       ...       ...
# 202         0.744303      0.197284    0.380597  0.082518  0.243131  0.819876
# 203         0.744303      0.197284    0.380597  0.082518  0.243131  0.819876
# 204         0.826800      0.413500    0.415423  0.075438  0.177352  0.819876
# 205         0.680720      0.170779    0.308458  0.070031  0.035387  0.701863
# 206         0.273929      0.481917    0.196517  0.031668  0.222731  0.453416
#
#      Avg Rent  Avg Disposable Income
# 0    0.374446               0.469189
# 1    0.139309               0.052072
# 2    0.048939               0.058221
# 3    0.097880               0.052400
# 4    0.136060               0.024362
# ..        ...                    ...
# 202  0.248299               0.629508
# 203  0.248299               0.629508
# 204  0.148389               0.423305
# 205  0.096532               0.299918
# 206  0.062103               0.049742
#
# [207 rows x 24 columns]

# %% [markdown]
# LabelEncoder

# %%
encoder=LabelEncoder()
final1=final.copy()
for item in final.select_dtypes(include="object").columns:
    final[item]=encoder.fit_transform(final[item])
final
# Out:
#      City  city_ascii      lat       lng  country  iso2  iso3  admin_name  \
# 0     178         178  35.6897  139.6922       35    40    40         151
# 1      88          88  -6.2146  106.8451       30    33    33          70
# 2      58          58  28.6600   77.2300       29    36    34          44
# 3     124         124  18.9667   72.8333       29    36    34          92
# 4     113         113  14.5958  120.9772       53    57    58          94
# ..    ...         ...      ...       ...      ...   ...   ...         ...
# 202    40          40  43.3972  -80.3114       12    13    13         116
# 203    40          40  43.3972  -80.3114       12    13    13         116
# 204    71          71  53.2729   -9.0418       32    34    35          53
# 205   166         166  35.9125   14.5019       42    48    48         138
# 206    27          27  40.8750  -74.0293       75    74    75         107
#
#      capital  population  ...  Health Care  Pollution  Quality of Life  \
# 0          2    1.000000  ...     0.674830   0.330448         0.729262
# 1          2    0.909478  ...     0.232930   0.626596         0.118163
# 2          0    0.779818  ...     0.720884   0.790197         0.423428
# 3          0    0.614893  ...     0.500200   0.762714         0.240884
# 4          2    0.607861  ...     0.795022   0.705691         0.089448
# ..       ...         ...  ...          ...        ...              ...
# 202        3    0.003202  ...     0.807267   0.618697         0.744303
# 203        3    0.003202  ...     0.807267   0.618697         0.744303
# 204        0    0.001874  ...     0.427792   0.567734         0.826800
# 205        0         NaN  ...     0.684014   0.733391         0.680720
# 206        3    0.000000  ...     0.706243   0.157325         0.273929
#
#      Crime Rating  Cappuccino    Cinema      Wine  Gasoline  Avg Rent  \
# 0        0.062671    0.457711  0.128605  0.266028  0.565217  0.374446
# 1        0.511294    0.353234  0.020082  0.611990  0.236025  0.139309
# 2        0.567306    0.094527  0.007724  0.212739  0.478261  0.048939
# 3        0.333203    0.094527  0.015577  0.162365  0.509317  0.097880
# 4        0.747487    0.278607  0.012358  0.109076  0.490683  0.136060
# ..            ...         ...       ...       ...       ...       ...
# 202      0.197284    0.380597  0.082518  0.243131  0.819876  0.248299
# 203      0.197284    0.380597  0.082518  0.243131  0.819876  0.248299
# 204      0.413500    0.415423  0.075438  0.177352  0.819876  0.148389
# 205      0.170779    0.308458  0.070031  0.035387  0.701863  0.096532
# 206      0.481917    0.196517  0.031668  0.222731  0.453416  0.062103
#
#      Avg Disposable Income
# 0                 0.469189
# 1                 0.052072
# 2                 0.058221
# 3                 0.052400
# 4                 0.024362
# ..                     ...
# 202               0.629508
# 203               0.629508
# 204               0.423305
# 205               0.299918
# 206               0.049742
#
# [207 rows x 24 columns]

# %% [markdown]
# ## Optimum K value and Model building

# %%
from sklearn.cluster import KMeans

# %%
final.population.fillna(final.population.mean(),inplace=True)
final.isna().sum()
# Out:
# City                     0
# city_ascii               0
# lat                      0
# lng                      0
# country                  0
# iso2                     0
# iso3                     0
# admin_name               0
# capital                  0
# population               0
# id                       0
# Country                  0
# Movehub Rating           0
# Purchase Power           0
# Health Care              0
# Pollution                0
# Quality of Life          0
# Crime Rating             0
# Cappuccino               0
# Cinema                   0
# Wine                     0
# Gasoline                 0
# Avg Rent                 0
# Avg Disposable Income    0
# dtype: int64

# %%
scores=[]
ks=[x for x in range(2,8)]
for i in ks:
    model=KMeans(n_clusters=i)
    model.fit(final.drop("id",axis=1))
    scores.append((i,model.inertia_))

#print(ks[scores.index(np.min(scores))])

# %%
sorted(scores,key=lambda x : x[1])
# Out:
# [(7, 1225386.3697698526),
#  (6, 1341100.539237198),
#  (5, 1511458.9888135039),
#  (4, 1704832.9698201155),
#  (3, 2020145.0887317965),
#  (2, 2506836.681283143)]

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
import matplotlib.cm as cm
import numpy as np
X=final
range_n_clusters = [4, 5, 6]
for n_clusters in range_n_clusters:
 # Create a subplot with 1 row and 2 columns
     fig, ax1 = plt.subplots(1, 1)
     ax1.set_xlim([-0.1, 1])
     ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])
     clusterer = KMeans(n_clusters=n_clusters, random_state=10)
     cluster_labels = clusterer.fit_predict(X)
     silhouette_avg = silhouette_score(X, cluster_labels)
     print("For n_clusters =", n_clusters,"The average silhouette_score is :", silhouette_avg)
 # Compute the silhouette scores for each sample
     sample_silhouette_values = silhouette_samples(X, cluster_labels)
     y_lower = 10
     for i in range(n_clusters):
         ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]
         ith_cluster_silhouette_values.sort()
         size_cluster_i = ith_cluster_silhouette_values.shape[0]
         y_upper = y_lower + size_cluster_i
         color = cm.nipy_spectral(float(i) / n_clusters)
         ax1.fill_betweenx(np.arange(y_lower, y_upper),0, ith_cluster_silhouette_values,facecolor=color, edgecolor=color, alpha=0.7)
 # Label the silhouette plots with their cluster numbers at the middle
         ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
 # Compute the new y_lower for next plot
         y_lower = y_upper + 10 # 10 for the 0 samples
         ax1.set_xlabel("The silhouette coefficient values")
         ax1.set_ylabel("Cluster label")
 # The vertical line for average silhouette score of all the values
         ax1.axvline(x=silhouette_avg, color="red", linestyle="--")
         ax1.set_yticks([]) # Clear the yaxis labels / ticks
         ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
plt.show()
# Out:
# For n_clusters = 4 The average silhouette_score is : 0.6779650789039215
# For n_clusters = 5 The average silhouette_score is : 0.6869236448199424
# For n_clusters = 6 The average silhouette_score is : 0.7021945648433535

# %%
model=KMeans(n_clusters=5)

# %%
model.fit(final.drop("id",axis=1))
clusters=model.predict(final.drop("id",axis=1))
final["Clusters"]=clusters

# %%
clust_count=[]
for item in set(clusters):
    print("Cluster :",item)
    clust_count.append(len(final.City[final.Clusters==item].unique()))
    print(final1.City[final.Clusters==item].unique(),"\n")
# Out:
# Cluster : 0
# ['Cairo' 'Buenos Aires' 'Chicago' 'Dallas' 'Atlanta' 'Belo Horizonte'
#  'Boston' 'Barcelona' 'Casablanca' 'Amman' 'Berlin' 'Detroit' 'Birmingham'
#  'Fortaleza' 'Antalya' 'Baku' 'Baltimore' 'Caracas' 'Bucharest' 'Curitiba'
#  'Budapest' 'Austin' 'Charlotte' 'Belgrade' 'Doha' 'Calgary' 'Dublin'
#  'Copenhagen' 'Cologne' 'Edmonton' 'Amsterdam' 'Abu Dhabi' 'Athens'
#  'Bratislava' 'Brussels' 'Glasgow' 'Frankfurt' 'Bristol' 'Hamilton'
#  'Edinburgh' 'Belfast' 'Alicante' 'Asheville' 'Bergen' 'Aachen' 'Aberdeen'
#  'Geneva' 'Cork' 'Basel' 'Braga' 'Brighton' 'Cambridge' 'Galway' 'Bogota']
#
# Cluster : 1
# ['Jakarta' 'Delhi' 'Manila' 'Beijing' 'Bangkok' 'Dhaka' 'Bangalore'
#  'Chennai' 'Kuala Lumpur' 'Hanoi' 'Hong Kong' 'Melbourne' 'Addis Ababa'
#  'Brisbane' 'Dubai' 'Indore' 'Davao' 'Auckland' 'Adelaide' 'Colombo'
#  'Cape Town' 'Canberra' 'Gaborone' 'Kochi' 'Gold Coast' 'Christchurch'
#  'Gurgaon' 'Darwin' 'Chiang Mai']
#
# Cluster : 2
# ['Mexico City' 'New York' 'Los Angeles' 'Lima' 'Santiago' 'Miami'
#  'Philadelphia' 'Houston' 'Toronto' 'Washington' 'Phoenix' 'Seattle'
#  'San Francisco' 'San Diego' 'Minneapolis' 'Tampa' 'Santo Domingo'
#  'Vancouver' 'Las Vegas' 'Portland' 'San Antonio' 'Quito' 'Orlando'
#  'Indianapolis' 'Porto Alegre' 'Valencia' 'Montevideo' 'Nashville'
#  'New Orleans' 'Ottawa' 'Victoria' 'Honolulu' 'Rochester' 'Newark'
#  'Regina']
#
# Cluster : 3
# ['Mumbai' 'Moscow' 'Lagos' 'Istanbul' 'Karachi' 'Lahore' 'London' 'Riyadh'
#  'Nairobi' 'Johannesburg' 'Madrid' 'Rome' 'Manchester' 'Minsk' 'Leeds'
#  'Hamburg' 'Munich' 'Kharkiv' 'Muscat' 'Milan' 'Nice' 'Jerusalem'
#  'Pretoria' 'Oslo' 'Helsinki' 'Lisbon' 'Nicosia' 'Ljubljana' 'Manama'
#  'Luxembourg' 'Naples' 'Marseille' 'Liverpool' 'Nottingham' 'Stuttgart'
#  'Gothenburg' 'Dresden' 'Lyon' 'Leicester' 'Florence' 'Haifa' 'Porto'
#  'Limassol' 'Oxford' 'Marbella' 'Lausanne']
#
# Cluster : 4
# ['Tokyo' 'Shanghai' 'Seoul' 'Tehran' 'Paris' 'Pune' 'Singapore'
#  'Saint Petersburg' 'Sydney' 'Taipei' 'Vadodara' 'Perth' 'Vienna' 'Warsaw'
#  'The Hague' 'Ulaanbaatar' 'Sofia' 'Prague' 'Rotterdam' 'Stockholm'
#  'Zagreb' 'Vilnius' 'Tirana' 'Wellington' 'Toulouse' 'Utrecht'
#  'Strasbourg' 'Varna' 'Venice' 'Trondheim' 'Stavanger' 'Sliema']

# %% [markdown]
# ## Geoplot

# %%
# plot clustered data onto map
from shapely.geometry import Point
import geopandas as gpd
geometry = [Point(xy) for xy in zip(final['lng'], final['lat'])]
gdf = gpd.GeoDataFrame(final, geometry=geometry)   

#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

gdf.plot(ax=world.plot(figsize=(20, 10)), marker='o', c=final.Clusters.astype(float), markersize=35);
